# %% [markdown]
# ### Импорт библиотек

# %%
import spacy
import pandas as pd
import nltk
import numpy as np
import re
from nltk.corpus import stopwords
from tqdm import tqdm
from collections import Counter, defaultdict
import itertools
from spacy.symbols import NOUN, PROPN, PUNCT, SYM, ADP, DET, ADJ

nlp = spacy.load("ru_core_news_lg")
stopwords_ru = stopwords.words("russian")
tqdm.pandas(desc="progress-bar")

# %% [markdown]
# ### Предобработка данных

# %%
df = pd.read_excel('review.xlsx')
df = df.drop('Unnamed: 0', axis=1)

# %%
df.head(5)
# Out:
#                                               review
# 0  День 8-го марта прошёл, можно и итоги подвести...
# 1  Отмечали в этом ресторане день рождение на пер...
# 2  Хочу поделиться своим впечатлением от посещени...
# 3  Добрый день! Были вчера с друзьями в этом кафе...
# 4  Отметили с мужем годовщину свадьбы 6 ноября в ...

# %%
df['review'][1]
# Out:
# 'Отмечали в этом ресторане день рождение на первом этаже в субботу вечером. Хочу выразить большую благодарность прежде всего руководству ресторана, обслуживающему персоналу и конечно же тем сотрудникам, которые готовят посетителям заведения столь вкусные блюда. Понравилось абсолютно все. Конечно же впечатляет интерьер: уютно и красиво. Стол был шикарный. Нас обслуживал официант Бахрам, спасибо ему. Хочу отметить, что для ресторана такого уровня цены не высокие.'

# %%
def sent_token(text):
    """
    Токенизация по предложениям
    """
    text = str(text).lower()
    text = text.replace('...', '.').replace('.', '. ')
    return [nlp(x, disable=["ner"]) for x in nltk.sent_tokenize(text)]

# %%
df["sentences"] = df["review"].progress_map(lambda x: sent_token(x))
# Out:
# progress-bar: 100%|██████████| 284/284 [00:31<00:00,  9.00it/s]

# %%
df = df.explode('sentences')
df.index = np.arange(0, len(df))

# %%
def process_sent(text, remove_stopwords=False, min_token_length=3):
    """ 
    Apply text preprocessing steps 
    """
    if remove_stopwords:
        return " ".join([token.lemma_.lower() for token in text if not token.is_stop 
                         and len(token.text) >= min_token_length])
    else:
        return " ".join([token.lemma_.lower() for token in text if len(token.text) >= min_token_length])

# %%
df['clean_sent'] = df['sentences'].progress_map(lambda x: process_sent(x))
# Out:
# progress-bar: 100%|██████████| 3466/3466 [00:00<00:00, 43614.77it/s]

# %% [markdown]
# ### Извлечение аспектных терминов

# %%
def get_noun_phrases(texts):
    
    features_dict = Counter()
    
    for item in tqdm(texts):
        text_nlp = nlp(item)
        count = 0
        half_chunk = ""
        for word in text_nlp:
            if word.tag_ in('NOUN', 'PROPN'):
                count+=1
                if count>=1:
                    half_chunk = half_chunk + str(word) + " "
            else:
                half_chunk = half_chunk + "---"
                count = 0
        half_chunk = re.sub(r"-+","?",half_chunk).split("?")
        half_chunk = [x.strip() for x in half_chunk if x!=""]
        
        half_chunk = [x for x in half_chunk if x != '']
    
        features_dict.update(half_chunk)
    return features_dict

# %%
features_dict = get_noun_phrases(list(df['clean_sent']))
# Out:
# 100%|██████████| 3466/3466 [00:42<00:00, 81.66it/s]

# %%
features_dict.most_common()
# Out:
# [('ресторан', 224),
#  ('место', 153),
#  ('кухня', 131),
#  ('раз', 131),
#  ('интерьер', 124),
#  ('заведение', 117),
#  ('обслуживание', 112),
#  ('меню', 103),
#  ('блюдо', 99),
#  ('столик', 92),
#  ('официант', 92),
#  ('еда', 75),
#  ('заказ', 74),
#  ('стол', 74),
#  ('вечер', 73),
#  ('минута', 71),
#  ('зал', 71),
#  ('время', 68),
#  ('человек', 63),
#  ('спасибо', 61),
#  ('порция', 58),
#  ('впечатление', 56),
#  ('гость', 55),
#  ('цена', 55),
#  ('персонал', 54),
#  ('музыка', 54),
#  ('пиво', 47),
#  ('день', 45),
#  ('официантка', 45),
#  ('салат', 44),
#  ('отзыв', 41),
#  ('атмосфера', 41),
#  ('девушка', 37),
#  ('десерт', 35),
#  ('компания', 33),
#  ('уровень', 32),
#  ('праздник', 27),
#  ('выбор', 27),
#  ('напиток', 27),
#  ('год', 27),
#  ('друг', 25),
#  ('минус', 25),
#  ('банкет', 25),
#  ('сервис', 24),
#  ('вкус', 24),
#  ('обстановка', 24),
#  ('дело', 23),
#  ('день рождение', 23),
#  ('народ', 23),
#  ('подруга', 23),
#  ('мясо', 23),
#  ('тарелка', 22),
#  ('вход', 22),
#  ('час', 22),
#  ('восторг', 21),
#  ('настроение', 21),
#  ('ребёнок', 21),
#  ('этаж', 20),
#  ('свадьба', 19),
#  ('кафе', 19),
#  ('счёт', 19),
#  ('соус', 18),
#  ('вино', 18),
#  ('муж', 18),
#  ('итог', 17),
#  ('администратор', 17),
#  ('удовольствие', 16),
#  ('суп', 15),
#  ('посетитель', 15),
#  ('ресторанчик', 14),
#  ('чай', 14),
#  ('паста', 14),
#  ('алкоголь', 13),
#  ('закуска', 13),
#  ('город', 13),
#  ('свет', 12),
#  ('ролл', 12),
#  ('посещение', 12),
#  ('взгляд', 12),
#  ('шашлык', 12),
#  ('слово', 11),
#  ('ожидание', 11),
#  ('рыба', 11),
#  ('претензия', 11),
#  ('район', 11),
#  ('стейк', 11),
#  ('благодарность', 10),
#  ('ребята', 10),
#  ('момент', 10),
#  ('окно', 10),
#  ('кофе', 10),
#  ('повар', 10),
#  ('дом', 10),
#  ('сожаление', 10),
#  ('пора', 10),
#  ('коктейль', 9),
#  ('пицца', 9),
#  ('клиент', 9),
#  ('бокал', 9),
#  ('отношение', 9),
#  ('работа', 9),
#  ('внимание', 9),
#  ('вид', 9),
#  ('руб.', 9),
#  ('случай', 9),
#  ('целое', 8),
#  ('паб', 8),
#  ('повод', 8),
#  ('ужин', 8),
#  ('карта', 8),
#  ('желание', 8),
#  ('качество', 8),
#  ('открытие', 8),
#  ('мужчина', 8),
#  ('неделя', 8),
#  ('принцип', 8),
#  ('стиль', 8),
#  ('помещение', 8),
#  ('выбор блюдо', 8),
#  ('сыр', 8),
#  ('сотрудник', 7),
#  ('стойка', 7),
#  ('конец', 7),
#  ('гардероб', 7),
#  ('скидка', 7),
#  ('кальян', 7),
#  ('вывод', 7),
#  ('пожелание', 7),
#  ('похвала', 7),
#  ('конец вечер', 7),
#  ('комната', 7),
#  ('название', 7),
#  ('сок', 7),
#  ('улыбка', 7),
#  ('мелочь', 7),
#  ('встреча', 7),
#  ('совет', 6),
#  ('диван', 6),
#  ('программа', 6),
#  ('просьба', 6),
#  ('суша', 6),
#  ('ночь', 6),
#  ('улица', 6),
#  ('коллега', 6),
#  ('торт', 6),
#  ('освещение', 6),
#  ('проблема', 6),
#  ('нарекание', 6),
#  ('центр', 6),
#  ('семья', 6),
#  ('вопрос', 6),
#  ('мина', 6),
#  ('компания человек', 6),
#  ('диванчик', 6),
#  ('местечко', 6),
#  ('март', 5),
#  ('жизнь', 5),
#  ('комментарий', 5),
#  ('аппетит', 5),
#  ('пятница', 5),
#  ('кухня обслуживание', 5),
#  ('спасибо персонал', 5),
#  ('чек', 5),
#  ('тон', 5),
#  ('родитель', 5),
#  ('салат цезарь', 5),
#  ('эмоция', 5),
#  ('мороженое', 5),
#  ('спутник', 5),
#  ('разу', 5),
#  ('танец', 5),
#  ('юбилей', 5),
#  ('ужас', 5),
#  ('глаз', 5),
#  ('девушка официантка', 5),
#  ('лето', 5),
#  ('морс', 5),
#  ('прибор', 5),
#  ('посуда', 5),
#  ('палочка', 5),
#  ('сайт', 5),
#  ('молодец', 5),
#  ('бармен', 5),
#  ('бар', 5),
#  ('рубль', 5),
#  ('правда', 5),
#  ('мнение', 5),
#  ('супчик', 5),
#  ('процветание', 5),
#  ('плюс', 5),
#  ('имя', 4),
#  ('утка', 4),
#  ('свинина', 4),
#  ('общение', 4),
#  ('выбор пиво', 4),
#  ('тирамису', 4),
#  ('туалет', 4),
#  ('хлеб', 4),
#  ('уголь', 4),
#  ('мера', 4),
#  ('любитель', 4),
#  ('котлетка', 4),
#  ('сравнение', 4),
#  ('информация', 4),
#  ('торжество', 4),
#  ('месяц', 4),
#  ('проведение', 4),
#  ('профессионал', 4),
#  ('деньга', 4),
#  ('воспоминание', 4),
#  ('беседа', 4),
#  ('шеф повар', 4),
#  ('дверь', 4),
#  ('наличие', 4),
#  ('жена', 4),
#  ('отдых', 4),
#  ('говядина', 4),
#  ('рот', 4),
#  ('предложение', 4),
#  ('мебель', 4),
#  ('сторона', 4),
#  ('продукт', 4),
#  ('гриб', 4),
#  ('радио', 4),
#  ('замечание', 4),
#  ('официант меню', 4),
#  ('решение', 4),
#  ('пепельница', 4),
#  ('фрукт', 4),
#  ('визит', 4),
#  ('оценка', 4),
#  ('соотношение цена качество', 4),
#  ('отсутствие', 4),
#  ('бронь', 4),
#  ('администрация', 4),
#  ('судак', 4),
#  ('зона', 4),
#  ('стена', 4),
#  ('апрель', 4),
#  ('млт', 4),
#  ('сдача', 3),
#  ('ура', 3),
#  ('гриль', 3),
#  ('персонал ресторан', 3),
#  ('суббота', 3),
#  ('минута официант', 3),
#  ('плед', 3),
#  ('размер', 3),
#  ('вход ресторан', 3),
#  ('вид окно', 3),
#  ('ценник', 3),
#  ('печень', 3),
#  ('половина', 3),
#  ('дизайн', 3),
#  ('филадельфия', 3),
#  ('бизнес ланч', 3),
#  ('реклама', 3),
#  ('центр зал', 3),
#  ('палтус', 3),
#  ('овощ', 3),
#  ('панакота', 3),
#  ('ощущение', 3),
#  ('понедельник', 3),
#  ('сорт', 3),
#  ('купон', 3),
#  ('январь', 3),
#  ('закуска салат', 3),
#  ('одежда', 3),
#  ('вариант', 3),
#  ('подача', 3),
#  ('шок', 3),
#  ('оформление', 3),
#  ('коллектив', 3),
#  ('директор', 3),
#  ('февраль', 3),
#  ('картофель', 3),
#  ('рис', 3),
#  ('пол', 3),
#  ('течение', 3),
#  ('банкет человек', 3),
#  ('выбор вино', 3),
#  ('удивление', 3),
#  ('выходной', 3),
#  ('няня', 3),
#  ('выбор алкоголь', 3),
#  ('впечатление заведение', 3),
#  ('уверенность', 3),
#  ('воскресение', 3),
#  ('часть', 3),
#  ('шарик', 3),
#  ('голова', 3),
#  ('сочетание', 3),
#  ('май', 3),
#  ('хачапури', 3),
#  ('баклажан', 3),
#  ('нога', 3),
#  ('очередь', 3),
#  ('рука', 3),
#  ('качество еда', 3),
#  ('ингредиент', 3),
#  ('недочёт', 3),
#  ('работа официант', 3),
#  ('стакан', 3),
#  ('задержка', 3),
#  ('шампанское', 3),
#  ('гардеробщик', 3),
#  ('чашка кофе', 3),
#  ('корзинка', 3),
#  ('книга', 3),
#  ('специя', 3),
#  ('обед', 3),
#  ('отличие', 3),
#  ('чаевой', 3),
#  ('фотография', 3),
#  ('пятница вечер', 3),
#  ('терраса', 3),
#  ('октябрь', 3),
#  ('ресторан обслуживание', 3),
#  ('стул', 3),
#  ('возможность', 3),
#  ('впечатление посещение', 3),
#  ('сказка', 3),
#  ('спасибо шеф повар', 3),
#  ('успех', 3),
#  ('удача', 3),
#  ('посиделок', 3),
#  ('исключение', 3),
#  ('арагви', 3),
#  ('чебурек', 3),
#  ('гарнир', 3),
#  ('бутылка', 3),
#  ('майкл', 3),
#  ('квас', 3),
#  ('отзыв ресторан', 2),
#  ('ведущий', 2),
#  ('ресторан день рождение', 2),
#  ('руководство ресторан', 2),
#  ('уровень цена', 2),
#  ('выбор меню', 2),
#  ('спасибо повар', 2),
#  ('вход девушка', 2),
#  ('ваза', 2),
#  ('веселие', 2),
#  ('многих', 2),
#  ('интерьер музыка', 2),
#  ('погода', 2),
#  ('красота', 2),
#  ('квартира', 2),
#  ('котлета', 2),
#  ('чувство юмор', 2),
#  ('выбор еда', 2),
#  ('куртка', 2),
#  ('образ', 2),
#  ('час минута', 2),
#  ('поход', 2),
#  ('учёт', 2),
#  ('проспект', 2),
#  ('кусок', 2),
#  ('антураж', 2),
#  ('караоке', 2),
#  ('креветка', 2),
#  ('минута стол', 2),
#  ('наполеон', 2),
#  ('вкус цвет товарищ', 2),
#  ('шоу', 2),
#  ('комплимент шеф повар', 2),
#  ('привет', 2),
#  ('тысяча', 2),
#  ('булочка', 2),
#  ('свадьба март', 2),
#  ('мероприятие', 2),
#  ('зал стол', 2),
#  ('220р', 2),
#  ('карандаш', 2),
#  ('сумма', 2),
#  ('качество обслуживание', 2),
#  ('разочарование', 2),
#  ('девушка администратор', 2),
#  ('положение', 2),
#  ('пара минута', 2),
#  ('обстановка ресторан', 2),
#  ('шпинат', 2),
#  ('ресторан август', 2),
#  ('спасибо администратор сергей', 2),
#  ('факт', 2),
#  ('угол', 2),
#  ('обслуживание балл', 2),
#  ('пара раз', 2),
#  ('полчаса', 2),
#  ('осадок', 2),
#  ('вентиляция', 2),
#  ('изыск', 2),
#  ('раз ресторан', 2),
#  ('ресторан раз', 2),
#  ('хозяин', 2),
#  ('меню ресторан', 2),
#  ('событие', 2),
#  ('идея', 2),
#  ('блюдо мясо', 2),
#  ('вопрос официантка', 2),
#  ('выбор пасть', 2),
#  ('ресторан март', 2),
#  ('фишка', 2),
#  ('состав', 2),
#  ('предпочтение еда', 2),
#  ('вцелом', 2),
#  ('горячий', 2),
#  ('выбор ресторан', 2),
#  ('отношение клиент', 2),
#  ('порог', 2),
#  ('комплимент', 2),
#  ('раз подруга', 2),
#  ('прелесть', 2),
#  ('течение минута', 2),
#  ('нарезка', 2),
#  ('высота', 2),
#  ('веранда', 2),
#  ('атмосфера заведение', 2),
#  ('прожарка', 2),
#  ('суббота вечер', 2),
#  ('подарок', 2),
#  ('центр город', 2),
#  ('бифштекс', 2),
#  ('выбор столик', 2),
#  ('спасибо ресторан', 2),
#  ('маргарита', 2),
#  ('многое', 2),
#  ('мысль', 2),
#  ('курица', 2),
#  ('тест', 2),
#  ('девушка официант', 2),
#  ('вывеска', 2),
#  ('пиво вкус', 2),
#  ('оливка', 2),
#  ('история', 2),
#  ('тепло', 2),
#  ('марка', 2),
#  ('грудка', 2),
#  ('салат холодильник', 2),
#  ('лаваш', 2),
#  ('заказ банкет', 2),
#  ('знакомых', 2),
#  ('пара день', 2),
#  ('группа', 2),
#  ('счастие', 2),
#  ('шоколад', 2),
#  ('тортик', 2),
#  ('панель', 2),
#  ('размер порция', 2),
#  ('италия', 2),
#  ('менеджер', 2),
#  ('свидание', 2),
#  ('идеал', 2),
#  ('правило', 2),
#  ('пирожок', 2),
#  ('минута ожидание', 2),
#  ('ответ', 2),
#  ('сила', 2),
#  ('контраст', 2),
#  ('карточка', 2),
#  ('тан жена', 2),
#  ('конина', 2),
#  ('заведение раз', 2),
#  ('оценка сервис', 2),
#  ('время ресторан', 2),
#  ('салями', 2),
#  ('условие', 2),
#  ('горе', 2),
#  ('сюрприз', 2),
#  ('выбор вина', 2),
#  ('гребешок', 2),
#  ('дождь', 2),
#  ('вид зал', 2),
#  ('аквариум', 2),
#  ('двор', 2),
#  ('раз спасибо', 2),
#  ('кофе чай', 2),
#  ('название блюдо', 2),
#  ('картинка', 2),
#  ('приход', 2),
#  ('пространство', 2),
#  ('пивоварня', 2),
#  ('блюдо напиток', 2),
#  ('молодец ребята', 2),
#  ('расположение центр город', 2),
#  ('метро', 2),
#  ('организация', 2),
#  ('многом', 2),
#  ('опасение', 2),
#  ('интерьер кухня персонал', 2),
#  ('куча', 2),
#  ('публика', 2),
#  ('концерт', 2),
#  ('уют', 2),
#  ('количество', 2),
#  ('рыбка', 2),
#  ('корзина', 2),
#  ('разговор', 2),
#  ('балл', 2),
#  ('масло', 2),
#  ('официант администратор', 2),
#  ('завязка', 2),
#  ('рекомендация', 2),
#  ('друзями', 2),
#  ('обстановка интерьер', 2),
#  ('дома', 2),
#  ('оценка ресторан', 2),
#  ('песня', 2),
#  ('деталь', 2),
#  ('комфорт', 2),
#  ('лестница', 2),
#  ('забегаловка', 2),
#  ('нельсон паб', 2),
#  ('блюдо меню', 2),
#  ('смузи', 2),
#  ('супруг', 2),
#  ('друг знакомым', 2),
#  ('день рождение муж', 2),
#  ('лапша креветками', 2),
#  ('возраст', 2),
#  ('тунец', 2),
#  ('администратор наталья', 2),
#  ('фонтан', 2),
#  ('композиция', 2),
#  ('интерьер ресторан', 2),
#  ('речь', 2),
#  ('крем суп', 2),
#  ('дым', 2),
#  ('сын', 2),
#  ('выбор десерт', 2),
#  ('тесто', 2),
#  ('крем', 2),
#  ('фото', 2),
#  ('танцпол', 2),
#  ('говядина свинина', 2),
#  ('пара', 2),
#  ('пропасть', 2),
#  ('крик', 2),
#  ('разнообразие меню', 2),
#  ('салат суп', 2),
#  ('качество приготовление', 2),
#  ('устрица', 2),
#  ('дама', 2),
#  ('отношение официант', 2),
#  ('телефон', 2),
#  ('пирог', 2),
#  ('некурящий', 2),
#  ('осьминог', 2),
#  ('июль', 2),
#  ('девочка', 2),
#  ('экран', 2),
#  ('оформление блюдо', 2),
#  ('футбол', 2),
#  ('тарелка пиво', 2),
#  ('недостаток', 2),
#  ('лицо', 2),
#  ('спасибо обслуживание', 2),
#  ('шутка', 2),
#  ('собеседник', 2),
#  ('суша бар', 2),
#  ('пункт', 2),
#  ('акция', 2),
#  ('пюре', 2),
#  ('абажур', 2),
#  ('состав блюдо', 2),
#  ('приготовление', 2),
#  ('рояль', 2),
#  ('подружка', 2),
#  ('цезарь', 2),
#  ('макароны', 2),
#  ('слава', 2),
#  ('распитие', 2),
#  ('ребят', 1),
#  ('город официант', 1),
#  ('руководство персонал спасибо', 1),
#  ('этаж суббота вечер', 1),
#  ('посетитель заведение', 1),
#  ('официант бахрам спасибо', 1),
#  ('впечатление посещение ресторан крапива', 1),
#  ('встреча ресторан', 1),
#  ('администратор светлана', 1),
#  ('обслуживание банкет официант', 1),
#  ('человек сожаление', 1),
#  ('ресторан атмосфера', 1),
#  ('посещение крапива', 1),
#  ('бивштексы', 1),
#  ('мастер', 1),
#  ('муж годовщина свадьба ноябрь', 1),
#  ('цвет', 1),
#  ('официант сергей', 1),
#  ('салат свинина', 1),
#  ('свинина кальян бутылка вино', 1),
#  ('упадут=)но впринципе', 1),
#  ('взгляд ресторан', 1),
#  ('меню порция', 1),
#  ('пара минута официант', 1),
#  ('меню паб', 1),
#  ('минута недочёт', 1),
#  ('забывчивость официантка', 1),
#  ('сигарета', 1),
#  ('гренок стейк претензия', 1),
#  ('цезар приправа многовато', 1),
#  ('салат рыба', 1),
#  ('слух', 1),
#  ('администратор официант сервис уровень', 1),
#  ('гость родственник молодожён', 1),
#  ('расположение график работа отзыв', 1),
#  ('слово сервис обслуживание', 1),
#  ('время бутылочка вино', 1),
#  ('телятина', 1),
#  ('маленький', 1),
#  ('компания человек суп вино', 1),
#  ('время удовольствие', 1),
#  ('обстановка интерьер меню', 1),
#  ('количество человек', 1),
#  ('диджей', 1),
#  ('музыка отсутствие подсветка', 1),
#  ('столом(хотя', 1),
#  ('меню телефон', 1),
#  ('депозит тыс', 1),
#  ('тыс.', 1),
#  ('мелочь конец', 1),
#  ('рейтинг ресторан', 1),
#  ('терраса лето', 1),
#  ('конждиционеру', 1),
#  ('аромат пицца', 1),
#  ('козинку', 1),
#  ('оценка заведение', 1),
#  ('тираму', 1),
#  ('рот туалет', 1),
#  ('кровь', 1),
#  ('романтик официантка', 1),
#  ('спасибо атмосфера угощение', 1),
#  ('минута плед официант', 1),
#  ('заказ овощ', 1),
#  ('муж официант', 1),
#  ('порция ребёнок', 1),
#  ('юбилей год', 1),
#  ('вечер макарену', 1),
#  ('салат язык морепродукт паэлью курица кролик', 1),
#  ('человек кальянщик', 1),
#  ('этаж окно', 1),
#  ('громкость', 1),
#  ('блюдо обстановка', 1),
#  ('администратор александр', 1),
#  ('хачапури сыр', 1),
#  ('минус минус', 1),
#  ('день командировка', 1),
#  ('коллега работа', 1),
#  ('заведение котлетка ролл', 1),
#  ('место суша', 1),
#  ('вопрос официант', 1),
#  ('шеф повар меню', 1),
#  ('расстройство', 1),
#  ('особенность суп', 1),
#  ('рыба стейк', 1),
#  ('бефстроганов пюре', 1),
#  ('стиль обслуживание', 1),
#  ('котлетка меню', 1),
#  ('пол час', 1),
#  ('бракосочетание прогулка город', 1),
#  ('фотограф интерьер зал vip', 1),
#  ('подарок шеф повар', 1),
#  ('вечер пятница суббота', 1),
#  ('часа 4!столы', 1),
#  ('спагетти', 1),
#  ('хочется!сам ресторан', 1),
#  ('уютно!но', 1),
#  ('минус ресторан', 1),
#  ('улица восстание сожаление', 1),
#  ('рай', 1),
#  ('то=', 1),
#  ('рассмотрение итог', 1),
#  ('место паста', 1),
#  ('цена вино', 1),
#  ('соотношение еда', 1),
#  ('претензия особа', 1),
#  ('заинтересованность', 1),
#  ('семером', 1),
#  ('удовлетворение обслуживание приём', 1),
#  ('стиль место', 1),
#  ('день муж офис авеню', 1),
#  ('кухня достоинство', 1),
#  ('официант претензия', 1),
#  ('день народ зал', 1),
#  ('дело обслуживание', 1),
#  ('свадьба ресторан фаворит', 1),
#  ('выпечка', 1),
#  ('расположение метро', 1),
#  ('интерьер присутствие', 1),
#  ('менеджер банкет анна', 1),
#  ('выбор блюдо напиток выпечка украшение зал', 1),
#  ('встреча отдых компания', 1),
#  ('кресло диванчик', 1),
#  ('спасибо шеф', 1),
#  ('блюдо банкет', 1),
#  ('ресторан ольга', 1),
#  ('выбор меню декорирование', 1),
#  ('территория гостиница', 1),
#  ('гостиница', 1),
#  ('номер', 1),
#  ('омлет', 1),
#  ('персонал оооочень', 1),
#  ('цена счёт скидка честь день рождения),но', 1),
#  ('момент официант', 1),
#  ('экземпляр', 1),
#  ('горячее+ бутылка вино салат счёт', 1),
#  ('10%обслуживание', 1),
#  ('карта обслуживание', 1),
#  ('чека наличные', 1),
#  ('вымогание', 1),
#  ('курьёз', 1),
#  ('право выбор', 1),
#  ('свеча', 1),
#  ('господин дама', 1),
#  ('капрезе медальон цезарь', 1),
#  ('спасибо ирина', 1),
#  ('форма обслуживание', 1),
#  ('дизайн кафе', 1),
#  ('украшен))я', 1),
#  ('день вторник сентябрь', 1),
#  ('долго', 1),
#  ('недолгим', 1),
#  ('бизнес ланч удивление', 1),
#  ('сытным', 1),
#  ('карта подарок', 1),
#  ('мотивация', 1),
#  ('борщ копчёность ролл гриль', 1),
#  ('рибай', 1),
#  ('стейк хаус', 1),
#  ('салат цезарь креветками', 1),
#  ('показатель качество', 1),
#  ('кафе чёрт куличках', 1),
#  ('заведение разу', 1),
#  ('время вру', 1),
#  ('пиар', 1),
#  ('ресторан марчеллис', 1),
#  ('час народ', 1),
#  ('палтус шпинат', 1),
#  ('вкусняшками', 1),
#  ('рюмочка', 1),
#  ('марчеллисе', 1),
#  ('отношение ребёнок', 1),
#  ('малыш', 1),
#  ('ресторанчикам', 1),
#  ('деликатес', 1),
#  ('совет начальник', 1),
#  ('дача', 1),
#  ('человек друг родственник', 1),
#  ('мисо суп город', 1),
#  ('рыба ролл', 1),
#  ('грудка гриль фрукт стейк тунец', 1),
#  ('стейль', 1),
#  ('медальон телятина овощ', 1),
#  ('объедение', 1),
#  ('спасибо персонал работа', 1),
#  ('банкет человек качество гость', 1),
#  ('число гость', 1),
#  ('сбор сладость фрукт', 1),
#  ('выбор столик блюдо меню', 1),
#  ('ланч боксы', 1),
#  ('успех процветание', 1),
#  ('местечко север', 1),
#  ('кафе бар ресторан', 1),
#  ('выпивка закуска', 1),
#  ('везение', 1),
#  ('коктейли', 1),
#  ('спасибо официантке', 1),
#  ('фон', 1),
#  ('спасибо радио', 1),
#  ('выполнение заказ', 1),
#  ('раз официантка', 1),
#  ('пива', 1),
#  ('минута официатка', 1),
#  ('слава бог', 1),
#  ('глобус', 1),
#  ('компания кафе', 1),
#  ('знакомство ресторан italy', 1),
#  ('сервис официантка', 1),
#  ('анчоус', 1),
#  ('майонез', 1),
#  ('утро', 1),
#  ('italy', 1),
#  ('окно столик диванчиками', 1),
#  ('моджо', 1),
#  ('хостес', 1),
#  ('вечер компания', 1),
#  ('вечер ожидание', 1),
#  ('музыка интерьер', 1),
#  ('обслуживание администрация', 1),
#  ('количество официант', 1),
#  ('ассортимент блюдо', 1),
#  ('домашний', 1),
#  ('уровень музыкант', 1),
#  ('скатерть', 1),
#  ('минус праздник выходной', 1),
#  ('комплимент мороженое', 1),
#  ('фотография стена', 1),
#  ('гость хозяин', 1),
#  ('питер', 1),
#  ('четвером', 1),
#  ('время кухня', 1),
#  ('руб человек', 1),
#  ('цена ресторан', 1),
#  ('список', 1),
#  ('примета', 1),
#  ('блюдо шампанское', 1),
#  ('день вечер', 1),
#  ('тбилисо', 1),
#  ('кухня муж', 1),
#  ('наркотик', 1),
#  ('результат', 1),
#  ('подруга пара неделя', 1),
#  ('скажешь', 1),
#  ('интерьер любитель', 1),
#  ('ресторан мангал', 1),
#  ('вид мясо принцип', 1),
#  ('ремонт', 1),
#  ('праздник день рождение', 1),
#  ('уровень персонал', 1),
#  ('заведение интерьер', 1),
#  ('повод кухня', 1),
#  ('блинчиками мясо', 1),
#  ('интерьер качество блюдо', 1),
#  ('цена раз', 1),
#  ('июнь', 1),
#  ('санторини свадьба обслуживание', 1),
#  ('еды', 1),
#  ('ценник дороговат', 1),
#  ('выбор санторини', 1),
#  ('гость еда', 1),
#  ('заведение случай юбилей', 1),
#  ('папа', 1),
#  ('цетр город', 1),
#  ('месторасполажения', 1),
#  ('столик официантка', 1),
#  ('чудо', 1),
#  ('кухни', 1),
#  ('восприятие блюдо', 1),
#  ('находка повар', 1),
#  ('юдюдо', 1),
#  ('смысл хорошоим', 1),
#  ('качество вина', 1),
#  ('любопытство', 1),
#  ('мамин юбилей', 1),
#  ('обслуживание претензия', 1),
#  ('vip зона стоимость', 1),
#  ('конкурент', 1),
#  ('паулайнере', 1),
#  ('повод столик', 1),
#  ('столик девушка мария', 1),
#  ('окрков пепельница', 1),
#  ('частота', 1),
#  ('оперативность', 1),
#  ('понедельник центр', 1),
#  ('масса ряд', 1),
#  ('парочка блюдо', 1),
#  ('кухня сочетание обслуживание', 1),
#  ('ход', 1),
#  ('музыка средам', 1),
#  ('караоке программа', 1),
#  ('салат тунец салат лисичка', 1),
#  ('сестра этаж', 1),
#  ('разнообразие блюдо', 1),
#  ('музыкант', 1),
#  ('ресторан рекомендация', 1),
#  ('15мин', 1),
#  ('заказ цена', 1),
#  ('салат порция', 1),
#  ('время пепельница разу', 1),
#  ('интерьер охранник', 1),
#  ('официант благо', 1),
#  ('минута обстановка ресторан', 1),
#  ('внимание кухня', 1),
#  ('настроение качетсва', 1),
#  ('нож', 1),
#  ('мрак', 1),
#  ('ресторан гость', 1),
#  ('убой', 1),
#  ('салат лагуна баклажан рулетики гриб', 1),
#  ('мясо рыба', 1),
#  ('рыба стейк форель', 1),
#  ('взгляд блюдо', 1),
#  ('обслуживание отношение персонал', 1),
#  ('тамаду', 1),
#  ('ресторан диму', 1),
#  ('человек профессионал', 1),
#  ('промах', 1),
#  ('исключение мелочь', 1),
#  ('ресторанчик месяц', 1),
#  ('суджук', 1),
#  ('вид закуска атмосфера', 1),
#  ('девушка(по', 1),
#  ('подход посетитель', 1),
#  ('впечатление уровень', 1),
#  ('город нева', 1),
#  ('посещение дача', 1),
#  ('рамка поиск ресторан', 1),
#  ('мужчина гардероб', 1),
#  ('улыбка настроение', 1),
#  ('край глаз', 1),
#  ('координата', 1),
#  ('почта меню', 1),
#  ('встреча гардероб', 1),
#  ('девушка официантка чек', 1),
#  ('луиза', 1),
#  ('коптильня', 1),
#  ('вкуснятина', 1),
#  ('сомнение повод выбор ресторан свадьба', 1),
#  ('вкус спутница', 1),
#  ('предпочтение', 1),
#  ('диван россыпь подушка', 1),
#  ('полумрак', 1),
#  ('память', 1),
#  ('спутница выбор вино', 1),
#  ('вкус цвет', 1),
#  ('медальон говядина', 1),
#  ('обслуживание человек', 1),
#  ('зов', 1),
#  ('ресторан час', 1),
#  ('лишний', 1),
#  ('улыбками предложение', 1),
#  ('дежурное!в', 1),
#  ('столик день', 1),
#  ('бокалах', 1),
#  ('салат стейк', 1),
#  ('водка пиво коктейль', 1),
#  ('дело вкус', 1),
#  ('селёдка', 1),
#  ('ресторан пара неделя', 1),
#  ('вкус телевизор', 1),
#  ('картина', 1),
#  ('фонтан центр зал', 1),
#  ('восток', 1),
#  ('комок', 1),
#  ('аншлаг', 1),
#  ('ресторан столик', 1),
#  ('конец город', 1),
#  ('заказ столик место', 1),
#  ('блюдо десерт', 1),
#  ('год качество еда обслуживание', 1),
#  ('постоянство признак професссионализма', 1),
#  ('муж сюрприз', 1),
#  ('выбор кухня', 1),
#  ('концертик', 1),
#  ('народ столик проблема', 1),
#  ('улица пиво', 1),
#  ('сорт пиво', 1),
#  ('сервис кухня атмосфера', 1),
#  ('телефон заведение', 1),
#  ('друг семьёй', 1),
#  ('друг день рождение', 1),
#  ('ресторан суббота число', 1),
#  ('жена час вечер народ', 1),
#  ('женщина', 1),
#  ('кино', 1),
#  ('паста блин морс муж', 1),
#  ('блин', 1),
#  ('морс хлеб', 1),
#  ('судьба', 1),
#  ('кухня претензия', 1),
#  ('запас час', 1),
#  ('официант бармен изюминка', 1),
#  ('заведение заказ', 1),
#  ('лимонад', 1),
#  ('стейк кусок', 1),
#  ('имхо', 1),
#  ('заведение многие', 1),
#  ('большинство знакомых', 1),
#  ('еда уровень', 1),
#  ('греческую(в греция', 1),
#  ('выбор салат', 1),
#  ('раз семья', 1),
#  ('место центр город', 1),
#  ('бизнес ланч меню', 1),
#  ('жасмин', 1),
#  ('обслуживание заведение', 1),
#  ('диванчик правда', 1),
#  ('начало празднование коллектив человек годовщина выпуск', 1),
#  ('блюдо частность', 1),
#  ('паста название', 1),
#  ('блюдо коллега', 1),
#  ('дело привычка', 1),
#  ('любитель десерт', 1),
#  ('поле зрение', 1),
#  ('перерыв', 1),
#  ('количество персона', 1),
#  ('дело принцип', 1),
#  ('воскременье вечер', 1),
#  ('впечатление посещение ресторан паб', 1),
#  ('половина блюдо меню наличие', 1),
#  ('вызов', 1),
#  ('офицантка', 1),
#  ('пиво окрестность', 1),
#  ('цезарь креветками курица', 1),
#  ('вид вкус', 1),
#  ('тепреь', 1),
#  ('врятли', 1),
#  ('карпоратив', 1),
#  ('год кафе кон', 1),
#  ...]

# %%
def feature_pruning(features_dict, features_list=[], min_support=3, min_percent=0.01, verbose=False):
    """
    
    """
    # Apply p-support pruning
    result = []
    pruned_features_dict = features_dict.copy()
    for k1, v1 in features_dict.items():
        # Find single word features and the support
        if len(k1.split())==1:
            p_support = v1
            if verbose:
                print(f'feature {k1} support={p_support}')
            # Calculate p_support by subtracting the number of times the single noun appears in other
            #   noun_phrases
            for k2, v2 in features_dict.items():
                if len(k2.split())!=1:
                    if k1 in k2:
                        p_support -= v2
                        if verbose:
                            print(f'feature {k1} found in {k2}, updated support={p_support}') 
            # If the final p_support value < min_support, remove this feacture
            if p_support < min_support:
                pruned_features_dict.pop(k1, None)
                if verbose:
                    print(f'feature {k1} removed, support={p_support}')
              
    # Apply frequent feature pruning
    features = []
    for k, v in pruned_features_dict.items():
        if v > int(len(df['clean_sent']) * min_percent):
            result.append(k)
            
    return result, pruned_features_dict

# %%
result, pruned_features_dict = feature_pruning(features_dict)

# %%
result
# Out:
# ['отзыв',
#  'ресторан',
#  'столик',
#  'заказ',
#  'человек',
#  'блюдо',
#  'меню',
#  'обслуживание',
#  'интерьер',
#  'вечер',
#  'кухня',
#  'персонал',
#  'стол',
#  'гость',
#  'музыка',
#  'спасибо',
#  'раз',
#  'заведение',
#  'атмосфера',
#  'место',
#  'десерт',
#  'цена',
#  'впечатление',
#  'еда',
#  'пиво',
#  'минута',
#  'порция',
#  'время',
#  'официантка',
#  'девушка',
#  'зал']
